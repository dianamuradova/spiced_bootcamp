# %%
import pandas as pd

# %%
df = pd.read_csv("Datafiniti_Womens_Shoes.csv")

# %%
df.head()
# Out:
#                      id             dateAdded           dateUpdated asins  \
# 0  AVpfEf_hLJeJML431ueH  2015-05-04T12:13:08Z  2018-01-29T04:38:43Z   NaN
# 1  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 2  AVpi74XfLJeJML43qZAc  2017-01-27T01:23:39Z  2018-01-03T05:21:54Z   NaN
# 3  AVpjXyCc1cnluZ0-V-Gj  2017-01-27T01:25:56Z  2018-01-04T11:52:35Z   NaN
# 4  AVphGKLPilAPnD_x1Nrm  2017-01-27T01:25:56Z  2018-01-18T03:55:18Z   NaN
#
#          brand                                         categories  \
# 0  Naturalizer  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 1     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 2     MUK LUKS  Clothing,Shoes,Women's Shoes,Women's Casual Sh...
# 3     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
# 4     MUK LUKS  Clothing,Shoes,Women's Shoes,All Women's Shoes...
#
#   primaryCategories                          colors                 dimension  \
# ...

# %%
df.columns


df.sort_values(by = ["brand"])
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 8632  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8622  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8623  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8624  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8625  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8626  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8627  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8628  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8629  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8633  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8630  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# ...

# %%
df.sort_values(by = ["brand"])
# Out:
#                         id             dateAdded           dateUpdated asins  \
# 8632  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8622  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8623  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8624  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8625  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8626  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8627  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8628  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8629  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8633  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# 8630  AV_Ee528Hh53nbDR_0vY  2017-11-16T10:51:55Z  2018-02-11T05:04:36Z   NaN
# ...

# %%
#Which brands have the highest prices?

most_expensive_shoes = df.groupby('brand')[['prices.amountMax']].mean().sort_values(by = ['prices.amountMax'], ascending=False)

# %%
most_expensive_shoes
# Out:
#                             prices.amountMax
# brand
# Red Wing                          345.950000
# Lowa                              199.950000
# Free People                       178.000000
# Arc'teryx                         170.000000
# Scarpa                            169.700000
# Frye                              165.450000
# On Footwear                       159.990000
# La Sportiva                       152.500000
# MLB                               151.240000
# Splendid                          150.807143
# SoftWalk                          145.950000
# Hoka One One                      144.235714
# Under Armour                      143.323333
# Laredo                            140.000000
# Salewa                            138.950000
# Salomon                           137.369355
# Adidas                            135.664286
# Birkenstock                       133.333333
# herstar                           130.000000
# Dansko                            130.000000
# ...

# %%
# %matplotlib inline
import pylab as plt

# %%
most_expensive_shoes.plot()

# %%
most_expensive_shoes = most_expensive_shoes[most_expensive_shoes["prices.amountMax"] > 150]

# %%
most_expensive_shoes.plot.bar()
plt.title("Most expensive shoe brands")
# Out:
# Text(0.5, 1.0, 'Most expensive shoe brands')

# %%
most_expensive_shoes["prices.amountMax"].mean()
# Out:
# 184.35871428571429

# %%
df.columns
# Out:
# Index(['id', 'dateAdded', 'dateUpdated', 'asins', 'brand', 'categories',
#        'primaryCategories', 'colors', 'dimension', 'ean', 'imageURLs', 'keys',
#        'manufacturer', 'manufacturerNumber', 'name', 'prices.amountMax',
#        'prices.amountMin', 'prices.availability', 'prices.color',
#        'prices.condition', 'prices.currency', 'prices.dateAdded',
#        'prices.dateSeen', 'prices.isSale', 'prices.merchant', 'prices.offer',
#        'prices.returnPolicy', 'prices.shipping', 'prices.size',
#        'prices.sourceURLs', 'sizes', 'sourceURLs', 'upc', 'weight'],
#       dtype='object')

# %%
#What is the average price of each distinct brand listed?
average_price_df = df.dropna(axis=0, subset=['prices.amountMin'])

# %%
df.shape
# Out:
# (10000, 34)

# %%
average_price_df.shape
# Out:
# (10000, 34)

# %%
average_price_df = df.dropna(axis=0, subset=['prices.amountMax'])

# %%
df.isnull().any()
# Out:
# id                     False
# dateAdded              False
# dateUpdated            False
# asins                   True
# brand                  False
# categories             False
# primaryCategories      False
# colors                  True
# dimension               True
# ean                     True
# imageURLs              False
# keys                   False
# manufacturer            True
# manufacturerNumber      True
# name                   False
# prices.amountMax       False
# prices.amountMin       False
# prices.availability     True
# prices.color           False
# prices.condition        True
# prices.currency        False
# prices.dateAdded        True
# prices.dateSeen        False
# prices.isSale          False
# prices.merchant         True
# prices.offer            True
# prices.returnPolicy     True
# prices.shipping         True
# prices.size            False
# prices.sourceURLs      False
# sizes                  False
# sourceURLs             False
# ...

# %%
sliced_average_price_df = average_price_df[['brand', 'prices.amountMin','prices.amountMax']]
sliced_average_price_df['average_price'] = (sliced_average_price_df['prices.amountMin'] + sliced_average_price_df['prices.amountMax'])/2
sliced_average_price_df
# Out:
# /Users/diana/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                 brand  prices.amountMin  prices.amountMax  average_price
# 0         Naturalizer             55.99             55.99         55.990
# 1            MUK LUKS             35.25             47.00         41.125
# 2            MUK LUKS             35.25             35.25         35.250
# 3            MUK LUKS             24.75             24.75         24.750
# 4            MUK LUKS             30.39             33.00         31.695
# 5           Soft Ones              7.90             14.00         10.950
# 6            MUK LUKS             12.79             24.00         18.395
# ...

# %%
average_price_per_brand = sliced_average_price_df.groupby('brand')[['average_price']].mean().sort_values(by = ['average_price'])
average_price_per_brand
# Out:
#                       average_price
# brand
# Unbranded                  6.803333
# Soft Ones                 10.950000
# Faded Glory               13.381250
# Victoria K.               15.880000
# Genuine Dickies           16.925000
# Earth Spirit              18.100000
# Danskin Now               19.740000
# Riverberry                24.990000
# forever collectibles      25.000000
# Mo Mo                     25.046667
# Carrini                   27.700000
# Silver Lilly              28.490000
# Unique Bargains           29.750000
# muk luks                  30.745000
# Sloggers                  32.440000
# Dr. Scholl's              32.980000
# Brinley Co.               33.567973
# Daniel Green              35.000000
# reef                      36.061429
# ELLIE SHOES               37.410000
# lc lauren conrad          38.812101
# seven7                    39.636429
# IB Non-Slip               39.990000
# apt. 9                    40.270738
# unionbay                  40.894545
# ...

# %%
import pylab as plt
average_price_per_brand.hist()
plt.title("Average prices of shoes per brand") 
plt.savefig("Average prices of shoes")
plt.figure(figsize=(50,50))
plt.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
clean_data = df.filter(['brand', 'prices.amountMax', 'prices.amountMin'])

# %%
clean_data
# Out:
#                 brand  prices.amountMax  prices.amountMin
# 0         Naturalizer             55.99             55.99
# 1            MUK LUKS             47.00             35.25
# 2            MUK LUKS             35.25             35.25
# 3            MUK LUKS             24.75             24.75
# 4            MUK LUKS             33.00             30.39
# 5           Soft Ones             14.00              7.90
# 6            MUK LUKS             24.00             12.79
# 7            MUK LUKS             24.00             12.79
# 8            MUK LUKS             59.00             39.88
# 9            MUK LUKS             59.00             47.99
# 10           MUK LUKS             59.00             36.99
# 11           MUK LUKS             95.00             62.80
# 12           MUK LUKS             68.00             41.27
# 13           MUK LUKS             68.00             44.88
# 14           MUK LUKS             69.00             44.88
# ...
